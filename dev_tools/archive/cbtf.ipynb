# %%
import shutil
import os
from pathlib import PurePath

banned_dirs = [
    'Dynamics',
    'Solid_Mechanics',
    'Statics',
    'mathjax',
    'static',
    '_astro'
]

home = os.path.join(os.getcwd(), 'dist')

home
# Out:
# '/home/jcrayb/Documents/GitHub/physicsref/dist'

# %%
def explore_dir_and_move(home, dir):
    print(os.path.join(home, dir))
    dirs = [d for d in os.listdir(os.path.join(home, dir)) if (os.path.isdir(os.path.join(os.path.join(home, dir), d)) and d not in banned_dirs)]
    htmls = [d for d in os.listdir(os.path.join(home, dir)) if (d == 'index.html')]
    js = [d for d in os.listdir(os.path.join(home, dir)) if (d[-3:] == '.js')]
    print(dirs, htmls, js)
    if dir != '':
        for h in htmls:
            try:
                
                ppth = PurePath(os.path.join(os.path.join(home, dir), h))
                file_name = ppth.parts[-2]+'.html'
                print(os.path.join("/".join(ppth.parts[:-2]), file_name))
                shutil.move(os.path.join(os.path.join(home, dir), h), os.path.join("/".join(ppth.parts[:-2]), file_name))
            except Exception as e:
                print(e)
                pass

        for j in js:
            try:
                
                ppth = PurePath(os.path.join(os.path.join(home, dir), j))
                file_name = ppth.parts[-2]+'.js'
                
                if j == 'canvases.js':
                    print(os.path.join("/".join(ppth.parts[:-2]), file_name))
                    shutil.move(os.path.join(os.path.join(home, dir), j), os.path.join("/".join(ppth.parts[:-2]), file_name))
                else:
                    print(os.path.join("/".join(ppth.parts[:-2]), j))
                    shutil.move(os.path.join(os.path.join(home, dir), j), os.path.join("/".join(ppth.parts[:-2]), j))
            except Exception as e:
                print(e)
                pass
        
    for d in dirs:
        explore_dir_and_move(home, os.path.join(dir, d))
    return dirs

# %%
explore_dir_and_move(home, '')
# Out:
# /home/jcrayb/Documents/GitHub/physicsref/dist/
# ['dyn', 'sta', 'sol'] ['index.html'] ['PrairieDraw.js', 'PrairieGeom.js', 'bootstrap.min.js', 'jquery-2.1.4.min.js', 'pageControl.js', 'sha1.js', 'sylvester.js']
# /home/jcrayb/Documents/GitHub/physicsref/dist/dyn
# ['particle_kinematics', 'particle_kinetics', 'rigid_body_kinetics', 'text', 'vector_calculus', 'vectors', 'contact_and_rolling', 'rigid_body_kinematics', 'work_and_energy'] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/dyn.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/dyn/particle_kinematics
# ['text'] ['index.html'] ['canvases.js']
# //home/jcrayb/Documents/GitHub/physicsref/dist/dyn/particle_kinematics.html
# //home/jcrayb/Documents/GitHub/physicsref/dist/dyn/particle_kinematics.js
# /home/jcrayb/Documents/GitHub/physicsref/dist/dyn/particle_kinematics/text
# [] [] []
# /home/jcrayb/Documents/GitHub/physicsref/dist/dyn/particle_kinetics
# ['text'] ['index.html'] ['particle_kinetics.js']
# //home/jcrayb/Documents/GitHub/physicsref/dist/dyn/particle_kinetics.html
# //home/jcrayb/Documents/GitHub/physicsref/dist/dyn/particle_kinetics.js
# /home/jcrayb/Documents/GitHub/physicsref/dist/dyn/particle_kinetics/text
# [] [] []
# /home/jcrayb/Documents/GitHub/physicsref/dist/dyn/rigid_body_kinetics
# [] ['index.html'] ['canvases.js']
# //home/jcrayb/Documents/GitHub/physicsref/dist/dyn/rigid_body_kinetics.html
# //home/jcrayb/Documents/GitHub/physicsref/dist/dyn/rigid_body_kinetics.js
# /home/jcrayb/Documents/GitHub/physicsref/dist/dyn/text
# [] [] []
# /home/jcrayb/Documents/GitHub/physicsref/dist/dyn/vector_calculus
# ['text'] ['index.html'] ['canvases.js']
# //home/jcrayb/Documents/GitHub/physicsref/dist/dyn/vector_calculus.html
# //home/jcrayb/Documents/GitHub/physicsref/dist/dyn/vector_calculus.js
# /home/jcrayb/Documents/GitHub/physicsref/dist/dyn/vector_calculus/text
# [] [] []
# /home/jcrayb/Documents/GitHub/physicsref/dist/dyn/vectors
# ['text'] ['index.html'] ['canvases.js', 'py_triples.js', 'worldCoastlineCompressed.js']
# //home/jcrayb/Documents/GitHub/physicsref/dist/dyn/vectors.html
# //home/jcrayb/Documents/GitHub/physicsref/dist/dyn/vectors.js
# //home/jcrayb/Documents/GitHub/physicsref/dist/dyn/py_triples.js
# //home/jcrayb/Documents/GitHub/physicsref/dist/dyn/worldCoastlineCompressed.js
# /home/jcrayb/Documents/GitHub/physicsref/dist/dyn/vectors/text
# [] [] []
# /home/jcrayb/Documents/GitHub/physicsref/dist/dyn/contact_and_rolling
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/dyn/contact_and_rolling.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/dyn/rigid_body_kinematics
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/dyn/rigid_body_kinematics.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/dyn/work_and_energy
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/dyn/work_and_energy.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta
# ['cartesian_coordinates', 'introduction', 'text', 'vectors_scalars', 'blanktopic', 'centers_of_mass', 'forcesystems', 'free_body_diagrams', 'friction', 'hydrostatic_fluid_pressure', 'shear_moment_diagrams', 'moment_of_inertia', 'moments', 'reaction_forces', 'trusses', 'virtual_work'] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/cartesian_coordinates
# ['text'] ['index.html'] ['canvases.js']
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/cartesian_coordinates.html
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/cartesian_coordinates.js
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/cartesian_coordinates/text
# [] [] []
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/introduction
# ['text'] ['index.html'] ['canvases.js']
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/introduction.html
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/introduction.js
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/introduction/text
# [] [] []
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/text
# [] [] []
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/vectors_scalars
# ['text'] ['index.html'] ['canvases.js']
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/vectors_scalars.html
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/vectors_scalars.js
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/vectors_scalars/text
# [] [] []
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/blanktopic
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/blanktopic.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/centers_of_mass
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/centers_of_mass.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/forcesystems
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/forcesystems.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/free_body_diagrams
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/free_body_diagrams.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/friction
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/friction.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/hydrostatic_fluid_pressure
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/hydrostatic_fluid_pressure.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/shear_moment_diagrams
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/shear_moment_diagrams.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/moment_of_inertia
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/moment_of_inertia.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/moments
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/moments.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/reaction_forces
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/reaction_forces.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/trusses
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/trusses.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sta/virtual_work
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sta/virtual_work.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sol
# ['axial_loading', 'beam_deflection', 'bending', 'buckling', 'combined_loading', 'failure_theories', 'material_properties', 'pressure_vessels', 'shear_moment_diagrams', 'strain', 'stress', 'stress_transformation', 'torsion', 'transverse_shear'] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sol.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sol/axial_loading
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sol/axial_loading.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sol/beam_deflection
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sol/beam_deflection.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sol/bending
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sol/bending.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sol/buckling
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sol/buckling.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sol/combined_loading
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sol/combined_loading.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sol/failure_theories
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sol/failure_theories.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sol/material_properties
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sol/material_properties.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sol/pressure_vessels
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sol/pressure_vessels.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sol/shear_moment_diagrams
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sol/shear_moment_diagrams.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sol/strain
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sol/strain.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sol/stress
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sol/stress.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sol/stress_transformation
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sol/stress_transformation.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sol/torsion
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sol/torsion.html
# /home/jcrayb/Documents/GitHub/physicsref/dist/sol/transverse_shear
# [] ['index.html'] []
# //home/jcrayb/Documents/GitHub/physicsref/dist/sol/transverse_shear.html
# ['dyn', 'sta', 'sol']

# %% [markdown]
# ## Pages with content

# %%
links_to_replace = {
    "href=\"/favicon2.png\"":"href=\"../favicon2.png\"",
    "href=\"/bootstrap.min.css\"": "href=\"../bootstrap.min.css\"",
    "src=\"/bootstrap.min.js\"": "src=\"../bootstrap.min.js\"",
    "src=\"/mathjax/tex-chtml.js\"": "src=\"../mathjax/tex-chtml.js\"",
    "src=\"/jquery-2.1.4.min.js\"": "src=\"../jquery-2.1.4.min.js\"",
    "src=\"/PrairieDraw.js\"": "src=\"../PrairieDraw.js\"",
    "src=\"/PrairieGeom.js\"": "src=\"../PrairieGeom.js\"",
    "src=\"/sha1.js\"": "src=\"../sha1.js\"",
    "src=\"/sylvester.js\"": "src=\"../sylvester.js\"",
    "src=\"/static/js/simplified_view.js\"": "src=\"../static/js/simplified_view.js\"",
    "href=\"/static/css/main.css\"": "href=\"../static/css/main.css\"",
    "href=\"/static/css/sidebar.css\"": "href=\"../static/css/sidebar.css\"",
    'href="/"': 'href="../index.html"',
    "href=\"/sta\"": "href=\"../sta.html\"",
    "href=\"/sol\"": "href=\"../sol.html\"",
    "href=\"/dyn\"": "href=\"../dyn.html\"",
    "href=\"/sta/": "href=\"../sta/",
    "href=\"/sol/": "href=\"../sol/",
    "href=\"/dyn/": "href=\"../dyn/",
    "src=\"/sta/": "src=\"../sta/",
    "src=\"/sol/": "src=\"../sol/",
    "src=\"/dyn/": "src=\"../dyn/",
    "src=\"/sta/": "src=\"../sta/",
    "src=\"/sol/": "src=\"../sol/",
    "src=\"/dyn/": "src=\"../dyn/"
}

all_content_pages = os.listdir(os.path.join(home, 'sta')) + os.listdir(os.path.join(home, 'sol')) + os.listdir(os.path.join(home, 'dyn'))

all_content_pages = [p for p in all_content_pages if p[-5:] == '.html']

hrefs ={'/'+p.replace('.html', ''): '/'+p for p in all_content_pages}

for dir in ['dyn', 'sta', 'sol']:
    pages = [p for p in os.listdir(os.path.join(home, dir)) if p[-5:] == '.html']
    for page in pages:
        print(page)
        with open(os.path.join(home, os.path.join(dir, page)), 'r') as file:
            data = file.read()

        for wrong, correct in links_to_replace.items():
            data = data.replace(wrong, correct)

        for wrong, correct in hrefs.items():
            data = data.replace(wrong, correct)

        data = data.replace('.html/canvases', '')
        data = data.replace("../dyn/particle_kinetics.html/particle_kinetics.html.js", "../dyn/particle_kinetics.js")
        data = data.replace("../dyn/vectors.html/worldCoastlineCompressed.js", './worldCoastlineCompressed.js')
        data = data.replace("../dyn/vectors.html/py_triples.js", "./py_triples.js",)
        with open(os.path.join(home, os.path.join(dir, page)), 'w') as file:
            file.write(data)
# Out:
# particle_kinematics.html
# particle_kinetics.html
# rigid_body_kinetics.html
# vector_calculus.html
# vectors.html
# contact_and_rolling.html
# rigid_body_kinematics.html
# work_and_energy.html
# cartesian_coordinates.html
# introduction.html
# vectors_scalars.html
# blanktopic.html
# centers_of_mass.html
# forcesystems.html
# free_body_diagrams.html
# friction.html
# hydrostatic_fluid_pressure.html
# shear_moment_diagrams.html
# moment_of_inertia.html
# moments.html
# reaction_forces.html
# trusses.html
# virtual_work.html
# axial_loading.html
# beam_deflection.html
# bending.html
# buckling.html
# combined_loading.html
# failure_theories.html
# material_properties.html
# pressure_vessels.html
# shear_moment_diagrams.html
# strain.html
# stress.html
# stress_transformation.html
# torsion.html
# transverse_shear.html

# %% [markdown]
# ## Course home pages

# %%
links_to_replace = {
    "href=\"/favicon2.png\"":"href=\"./favicon2.png\"",
    "href=\"/bootstrap.min.css\"": "href=\"./bootstrap.min.css\"",
    "src=\"/bootstrap.min.js\"": "src=\"./bootstrap.min.js\"",
    "src=\"/mathjax/tex-chtml.js\"": "src=\"./mathjax/tex-chtml.js\"",
    "src=\"/jquery-2.1.4.min.js\"": "src=\"./jquery-2.1.4.min.js\"",
    "src=\"/PrairieDraw.js\"": "src=\"./PrairieDraw.js\"",
    "src=\"/PrairieGeom.js\"": "src=\"./PrairieGeom.js\"",
    "src=\"/sha1.js\"": "src=\"./sha1.js\"",
    "src=\"/sylvester.js\"": "src=\"./sylvester.js\"",
    "src=\"/static/js/simplified_view.js\"": "src=\"./static/js/simplified_view.js\"",
    "href=\"/static/css/main.css\"": "href=\"./static/css/main.css\"",
    "href=\"/static/css/sidebar.css\"": "href=\"./static/css/sidebar.css\"",
    'href="/"': 'href="./index.html"',
    "href=\"/sta\"": "href=\"./sta.html\"",
    "href=\"/sol\"": "href=\"./sol.html\"",
    "href=\"/dyn\"": "href=\"./dyn.html\"",
    "href=\"/sta/": "href=\"./sta/",
    "href=\"/sol/": "href=\"./sol/",
    "href=\"/dyn/": "href=\"./dyn/"
}

all_content_pages = os.listdir(os.path.join(home, 'sta')) + os.listdir(os.path.join(home, 'sol')) + os.listdir(os.path.join(home, 'dyn'))

all_content_pages = [p for p in all_content_pages if p[-5:] == '.html']

hrefs ={p.replace('.html', ''): p for p in all_content_pages}

for page in ['index.html', 'dyn.html', 'sta.html', 'sol.html']:
    print(page)
    with open(os.path.join(home, page), 'r') as file:
        data = file.read()

    for wrong, correct in links_to_replace.items():
        data = data.replace(wrong, correct)

    for wrong, correct in hrefs.items():
        data = data.replace(wrong, correct)
    
    with open(os.path.join(home, page), 'w') as file:
        file.write(data)
# Out:
# index.html
# dyn.html
# sta.html
# sol.html

# %%
all_content_pages
# Out:
# ['cartesian_coordinates.html',
#  'introduction.html',
#  'vectors_scalars.html',
#  'blanktopic.html',
#  'centers_of_mass.html',
#  'forcesystems.html',
#  'free_body_diagrams.html',
#  'friction.html',
#  'hydrostatic_fluid_pressure.html',
#  'shear_moment_diagrams.html',
#  'moment_of_inertia.html',
#  'moments.html',
#  'reaction_forces.html',
#  'trusses.html',
#  'virtual_work.html',
#  'axial_loading.html',
#  'beam_deflection.html',
#  'bending.html',
#  'buckling.html',
#  'combined_loading.html',
#  'failure_theories.html',
#  'material_properties.html',
#  'pressure_vessels.html',
#  'shear_moment_diagrams.html',
#  'strain.html',
#  'stress.html',
#  'stress_transformation.html',
#  'torsion.html',
#  'transverse_shear.html',
#  'particle_kinematics.html',
#  'particle_kinetics.html',
#  'rigid_body_kinetics.html',
#  'vector_calculus.html',
#  'vectors.html',
#  'contact_and_rolling.html',
#  'rigid_body_kinematics.html',
#  'work_and_energy.html']

# %%
import os

_astro = os.listdir('../dist/_astro')

css = [c for c in _astro if c[-4:] == '.css']
js = [j for j in _astro if j[-3:] == '.js']

links_to_replace = {
    "url(/fonts/source-sans-pro/SourceSansPro-Regular.otf": "url(./fonts/source-sans-pro/SourceSansPro-Regular.otf",
    "url(/fonts/source-sans-pro/SourceSansPro-Bold.otf": "url(./fonts/source-sans-pro/SourceSansPro-Bold.otf"
}

for file in css:
    name = os.path.join('../dist/_astro', file)

    with open(name, 'r') as f:
        data = f.read()

    for wrong, correct in links_to_replace.items():
        data = data.replace(wrong, correct)
    
    with open(name, 'w') as f:
        f.write(data)
